# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time
import pandas as pd

# %%
nama_produk = []
harga_produk = []
list_penjual = []
kota_toko = []
banyak_terjual = []
rating_produk = []

options = webdriver.ChromeOptions()
options.add_argument("enable-automation")
options.add_argument("useAutomationExtension")
options.add_argument("--no-sandbox")
options.add_argument("--disable-extensions")
options.add_argument("--dns-prefetch-disable")
options.add_argument("window-size=1920,1080")


driver = webdriver.Chrome(options=options)

# Ambil 10 halaman data
for i in range(1,110):
# Inisialisasi WebDriver
    
    url = 'https://www.tokopedia.com/search?navsource=&sc=1800&search_id=20241215062644D987C39936289E3340VF&srp_component_id=04.06.00.00&srp_page_id=&srp_page_title=&st=&q=sepatu&page={}'.format(i)
    driver.get(url)

    for i in range(22):
        driver.execute_script("window.scrollBy(0, 250)")
        time.sleep(1)

    driver.execute_script("window.scrollBy(50,0)")
    time.sleep(5)

    # Ambil konten halaman setelah dirender oleh JavaScript
    html = driver.page_source

    # Parse dengan BeautifulSoup
    soup = BeautifulSoup(html, 'html.parser')

    # Menyimpan semua produk yang memiliki class `css-5wh65g` dalam satu list `list_produk`
    list_produk = soup.find_all('div', {"class":"css-5wh65g"})

    # Ekstrak elemen web yang menampilkan nama produk, harga produk, nama toko, kota toko,jumlah terjual, dan rating dengan memanggil nama class-nya
    # try dan except untuk menghandling error jika data kosong sehingga bisa ditambahkan data None
    for produk in list_produk:
        try:
            nama = produk.find('div', {"class":"_6+OpBPVGAgqnmycna+bWIw=="}).get_text()
            nama_produk.append(nama)
        except:
            nama_produk.append(None)
        
        try:
            harga = produk.find('div', {"class":"_67d6E1xDKIzw+i2D2L0tjw=="}).get_text() 
            harga_produk.append(harga)
        except:
            harga_produk.append(None)
        
        try:
            penjual = produk.find('span', {"class":"T0rpy-LEwYNQifsgB-3SQw== pC8DMVkBZGW7-egObcWMFQ== flip"}).get_text()  # Nama produk
            list_penjual.append(penjual)
        except:
            list_penjual.append(None)
        
        try:
            kota = produk.find('span', {"class":"pC8DMVkBZGW7-egObcWMFQ== flip"}).get_text()  # Nama produk
            kota_toko.append(kota)
        except:
            kota_toko.append(None)
        
        try:
            terjual = produk.find('span', {"class":"se8WAnkjbVXZNA8mT+Veuw=="}).get_text()  # Nama produk
            banyak_terjual.append(terjual)
        except:
            banyak_terjual.append(None)

        try:
            rating = produk.find('span', {"class":"_9jWGz3C-GX7Myq-32zWG9w=="}).get_text()  # Nama produk
            rating_produk.append(rating)
        except:
            rating_produk.append(None)
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Cell In[13], line 27
#      24 driver.get(url)
#      26 for i in range(22):
# ---> 27     driver.execute_script("window.scrollBy(0, 250)")
#      28     time.sleep(1)
#      30 driver.execute_script("window.scrollBy(50,0)")
#
# File d:\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:414, in WebDriver.execute_script(self, script, *args)
#     411 converted_args = list(args)
#     412 command = Command.W3C_EXECUTE_SCRIPT
# --> 414 return self.execute(command, {"script": script, "args": converted_args})["value"]
#
# File d:\anaconda3\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File d:\anaconda3\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchWindowException: Message: no such window: target window already closed
# from unknown error: web view not found
#   (Session info: chrome=131.0.6778.140)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF651B06CC5+28821]
# 	(No symbol) [0x00007FF651A73850]
# 	(No symbol) [0x00007FF65191578A]
# 	(No symbol) [0x00007FF6518EF4F5]
# 	(No symbol) [0x00007FF651996247]
# 	(No symbol) [0x00007FF6519AECE2]
# 	(No symbol) [0x00007FF65198F0A3]
# 	(No symbol) [0x00007FF65195A778]
# 	(No symbol) [0x00007FF65195B8E1]
# 	GetHandleVerifier [0x00007FF651E3FCCD+3408029]
# 	GetHandleVerifier [0x00007FF651E5743F+3504143]
# 	GetHandleVerifier [0x00007FF651E4B61D+3455469]
# 	GetHandleVerifier [0x00007FF651BCBDCB+835995]
# 	(No symbol) [0x00007FF651A7EB6F]
# 	(No symbol) [0x00007FF651A7A824]
# 	(No symbol) [0x00007FF651A7A9BD]
# 	(No symbol) [0x00007FF651A6A1A9]
# 	BaseThreadInitThunk [0x00007FF8E1D07374+20]
# 	RtlUserThreadStart [0x00007FF8E3C1CC91+33]

# %%
# Menutup driver
driver.quit()

# %%
# Membuat DataFrame dari semua kolom yang telah di scrapping
data_list = list(zip(nama_produk, harga_produk, list_penjual, kota_toko, banyak_terjual, rating_produk))
data = pd.DataFrame(data_list,columns=['nama_produk', 'harga_produk', 'penjual', 'kota_toko', 'banyak_terjual', 'rating_produk'])

# %%
data
# Out:
#                                             nama_produk harga_produk  \
# 0     sepatu pria sneakers kets casual fashion terba...    Rp250.000
# 1     sepatu casual sneakers santai terbaru pria tre...    Rp180.000
# 2     sepatu sekolah pria sneakers fashion casual tr...    Rp200.000
# 3                           SEPATU ON CLOUD 5 BLACK ALL    Rp650.000
# 4     Sepatu Pria Running Skechers Gorun 600 Revel O...    Rp549.000
# ...                                                 ...          ...
# 8337                                               None         None
# 8338                                               None         None
# 8339                                               None         None
# 8340                                               None         None
# 8341                                               None         None
#
#               penjual        kota_toko banyak_terjual rating_produk
# 0      Good Father 40  Jakarta Selatan           None          None
# 1      Good Father 40  Jakarta Selatan      3 terjual          None
# 2      Good Father 40  Jakarta Selatan      6 terjual           2.5
# 3       NEW BALANCEEE  Jakarta Selatan     15 terjual           5.0
# 4     Benjamin Sports            Depok      3 terjual          None
# ...               ...              ...            ...           ...
# 8337             None             None           None          None
# 8338             None             None           None          None
# 8339             None             None           None          None
# 8340             None             None           None          None
# 8341             None             None           None          None
#
# [8342 rows x 6 columns]

# %%
data.to_csv("eda2.csv", index=False)
